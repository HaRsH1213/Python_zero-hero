# %% [markdown]
# <h2 align="center">AtliQ Hotels Data Analysis Project<h2>

# %%
import pandas as pd

# %%
df_bookings=pd.read_csv('datasets/fact_bookings.csv')
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_date=pd.read_csv('datasets/dim_date.csv')
df_hotels=pd.read_csv('datasets/dim_hotels.csv')
df_rooms=pd.read_csv('datasets/dim_rooms.csv')
df_agg_bookings=pd.read_csv('datasets/fact_aggregated_bookings.csv')

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# ***
# **Exercise: Explore aggregate bookings**
# ***

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %% [markdown]
# **Exercise-1. Find out unique property ids in aggregate bookings dataset**

# %%
# write your code here

df_agg_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560], dtype=int64)

# %% [markdown]
# **Exercise-2. Find out total bookings per property_id**

# %%
# write your code here
df_agg_bookings.groupby('property_id')['successful_bookings'].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %% [markdown]
# **Exercise-3. Find out days on which bookings are greater than capacity**

# %%
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %% [markdown]
# **Exercise-4. Find out properties that have highest capacity**

# %%
df_agg_bookings.capacity.max()
# Out:
# 50.0

# %%
df_agg_bookings[df_agg_bookings.capacity==df_agg_bookings.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %% [markdown]
# ***
# ### ==> 2. Data Cleaning
# ***

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# - min no_guests less then 1 is impossible so check out how many data in this df like this

# %%
df_bookings[df_bookings.no_guests<1]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings[df_bookings.no_guests<1].shape
# Out:
# (9, 12)

# %% [markdown]
# - only 9 row have error like this so we can remove this row from df it will not affect the records to much as df is too big

# %%
df_bookings= df_bookings[df_bookings.no_guests>0]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134578.000000  134578.000000   56679.000000       1.345780e+05
# mean    18061.143315       2.036744       3.619048       1.537804e+04
# std      1093.053454       1.031710       1.234970       9.304015e+04
# min     16558.000000       1.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134578.000000
# mean       12696.011822
# std         6927.841641
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings['revenue_generated'].min(),df_bookings['revenue_generated'].max()
# Out:
# (6500, 28560000)

# %% [markdown]
# - 28560000 Rs per night for a hotel is impossible it is oulier
# - To remove the oulier we are using 3 std deviation

# %%
mean,std= df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()

# %%
mean,std
# Out:
# (15378.036937686695, 93040.1549314641)

# %%
std_3= mean + 3*std
std_3
# Out:
# 294498.50173207896

# %% [markdown]
# - so any value in revenue_genrated is greater than this 3 std deviation is outlier

# %%
df_bookings[df_bookings.revenue_generated<std_3]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134578.000000  134578.000000   56679.000000       1.345780e+05
# mean    18061.143315       2.036744       3.619048       1.537804e+04
# std      1093.053454       1.031710       1.234970       9.304015e+04
# min     16558.000000       1.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134578.000000
# mean       12696.011822
# std         6927.841641
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# **by analysising revenue_realised col this col might be outlier so chck out this by 3 std rule**

# %%
std_3_realized=12696.011822+3*6927.841641
std_3_realized
# Out:
# 33479.536745000005

# %% [markdown]
# **lets check out how many data is grater than 3std in df**

# %%
df_bookings[df_bookings.revenue_realized> std_3_realized]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %% [markdown]
# **1300 row are there but common i all are from RT4 room category lets check out what is romm RT4**

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %% [markdown]
# **RT4 is a presidential room i tjink that why its price is high but for confirmation lets explore this room category more**

# %%
df_bookings[df_bookings.room_category=='RT4']
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 47       May012216558RT41        16558     26-04-22      1/5/2022
# 48       May012216558RT42        16558     27-04-22      1/5/2022
# 49       May012216558RT43        16558     29-04-22      1/5/2022
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 138      May012216559RT42        16559    11/4/2022      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 47          3/5/2022        2.0           RT4          logtrip            NaN
# ...

# %% [markdown]
# **Lets apply discribe funciton to this df revenue_realized to know more about this df**

# %%
df_bookings[df_bookings.room_category=='RT4'].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %% [markdown]
# **lets verfiy oulier by using 3std**

# %%
23439.308444+3*9048.599076
# Out:
# 50585.105672000005

# %% [markdown]
# **We can see that 3std(50585.105672000005) is greater than max(45220.000000) means all value of this df room cataegory revenue realzed is under 3std so it means their si no oulier in revenue_realized col**

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77899
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# Total values in our dataframe is 134576. Out of that 77899 rows has null rating. Since there are many rows with null rating, we should not filter these values. Also we should not replace this rating with a median or mean rating etc

# %% [markdown]
# **Exercise-1. In aggregate bookings find columns that have null values. Fill these null values with whatever you think is the appropriate subtitute (possible ways is to use mean or median)**

# %%
df_agg_bookings.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_agg_bookings[df_agg_bookings.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
median=df_agg_bookings.capacity.median()
median
# Out:
# 25.0

# %%
df_agg_bookings.fillna(median,inplace=True)

# %%
df_agg_bookings.loc[[8,14]]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22      25.0
# 14        17562      1-May-22           RT1                   12      25.0

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               0
# dtype: int64

# %% [markdown]
# **Exercise-2. In aggregate bookings find out records that have successful_bookings value greater than capacity. Filter those records**

# %%
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings=df_agg_bookings[df_agg_bookings.successful_bookings<=df_agg_bookings.capacity]
df_agg_bookings.shape
# Out:
# (9194, 5)

# %% [markdown]
# ***
# ### ==> 3. Data Transformation
# ***

# %%
df_agg_bookings.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings['occ_pct']=df_agg_bookings["successful_bookings"]/df_agg_bookings['capacity']
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667

# %%
(df_agg_bookings['occ_pct']*100).round(2)
# Out:
# 0       83.33
# 1       93.33
# 2       76.67
# 4       94.74
# 5       70.00
#         ...
# 9195    72.22
# 9196    72.22
# 9197    50.00
# 9198    50.00
# 9199    75.00
# Name: occ_pct, Length: 9194, dtype: float64

# %%
df_agg_bookings['occ_pct']=df_agg_bookings['occ_pct'].apply(lambda x: round(x*100,2))
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67

# %%
df_agg_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9194 entries, 0 to 9199
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9194 non-null   int64
#  1   check_in_date        9194 non-null   object
#  2   room_category        9194 non-null   object
#  3   successful_bookings  9194 non-null   int64
#  4   capacity             9194 non-null   float64
#  5   occ_pct              9194 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 502.8+ KB

# %% [markdown]
# There are various types of data transformations that you may have to perform based on the need. Few examples of data transformations are,
#
# 1. Creating new columns
# 1. Normalization
# 1. Merging data
# 1. Aggregation

# %% [markdown]
# ***
# ### ==> 4. Insights Generation
# ***

# %% [markdown]
# **1. What is an average occupancy rate in each of the room categories?**

# %%
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67

# %%
df_agg_bookings.groupby('room_category')['occ_pct'].mean()
# Out:
# room_category
# RT1    57.889643
# RT2    58.009756
# RT3    58.028213
# RT4    59.277925
# Name: occ_pct, dtype: float64

# %% [markdown]
# I don't understand RT1, RT2 etc. Print room categories such as Standard, Premium, Elite etc along with average occupancy percentage

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df=df_agg_bookings.merge(df_rooms,left_on='room_category',right_on='room_id')
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3    94.74     RT1   Standard

# %%
df.drop('room_id',axis=1,inplace=True)

# %%
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           16558      1-May-22           RT1                   18      19.0
# 4           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9189        16563     31-Jul-22           RT4                   13      18.0
# 9190        16559     31-Jul-22           RT4                   13      18.0
# 9191        17558     31-Jul-22           RT4                    3       6.0
# 9192        19563     31-Jul-22           RT4                    3       6.0
# 9193        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_pct    room_class
# ...

# %%
df.groupby('room_class')['occ_pct'].mean()
# Out:
# room_class
# Elite           58.009756
# Premium         58.028213
# Presidential    59.277925
# Standard        57.889643
# Name: occ_pct, dtype: float64

# %% [markdown]
# **2. Print average occupancy rate per city**

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df=df.merge(df_hotels,on='property_id')
df.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#    occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore
# 3    94.74   Standard   Atliq Grands    Luxury      Delhi
# 4    70.00   Standard     Atliq City  Business     Mumbai

# %%
df.groupby('city').occ_pct.mean()
# Out:
# city
# Bangalore    56.332376
# Delhi        61.507341
# Hyderabad    58.120652
# Mumbai       57.909181
# Name: occ_pct, dtype: float64

# %% [markdown]
# **3. When was the occupancy better? Weekday or Weekend?**

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df=df.merge(df_date,left_on='check_in_date',right_on='date')
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
#
#    occ_pct room_class property_name  category       city       date  mmm yy  \
# 0    51.72    Premium  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 1    63.33   Standard    Atliq City  Business  Hyderabad  10-May-22  May 22
# 2    60.00   Standard     Atliq Bay    Luxury  Bangalore  10-May-22  May 22
# 3    53.33   Standard  Atliq Palace  Business  Bangalore  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# 1    W 20  weekeday
# 2    W 20  weekeday
# 3    W 20  weekeday

# %%
df.drop('date',inplace=True,axis=1)

# %%
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
#
#    occ_pct room_class property_name  category       city  mmm yy week no  \
# 0    51.72    Premium  Atliq Palace  Business  Bangalore  May 22    W 20
# 1    63.33   Standard    Atliq City  Business  Hyderabad  May 22    W 20
# 2    60.00   Standard     Atliq Bay    Luxury  Bangalore  May 22    W 20
# 3    53.33   Standard  Atliq Palace  Business  Bangalore  May 22    W 20
#
#    day_type
# 0  weekeday
# 1  weekeday
# 2  weekeday
# 3  weekeday

# %%
df.groupby('day_type')['occ_pct'].mean().round(2)
# Out:
# day_type
# weekeday    50.88
# weekend     72.34
# Name: occ_pct, dtype: float64

# %% [markdown]
# **4: In the month of June, what is the occupancy for different cities**

# %%
df['mmm yy'].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june=df[df['mmm yy']=='Jun 22']
df_june.head()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
# 2203        17558     10-Jun-22           RT1                    9      19.0
# 2204        16558     10-Jun-22           RT1                   11      19.0
#
#       occ_pct room_class  property_name  category       city  mmm yy week no  \
# 2200    66.67   Standard  Atliq Exotica    Luxury     Mumbai  Jun 22    W 24
# 2201    63.33   Standard      Atliq Bay    Luxury  Bangalore  Jun 22    W 24
# 2202    56.67   Standard   Atliq Palace  Business  Bangalore  Jun 22    W 24
# 2203    47.37   Standard   Atliq Grands    Luxury     Mumbai  Jun 22    W 24
# 2204    57.89   Standard   Atliq Grands    Luxury      Delhi  Jun 22    W 24
#
#       day_type
# 2200  weekeday
# ...

# %%
df.groupby('city')['occ_pct'].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        60.40
# Hyderabad    56.90
# Mumbai       56.78
# Bangalore    55.18
# Name: occ_pct, dtype: float64

# %%
df.groupby('city')['occ_pct'].mean().round(2).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# **5: We got new data for the month of august. Append that to existing data**

# %%
df_august= pd.read_csv('datasets/new_data_august.csv')
df_august.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'room_class', 'property_name', 'category',
#        'city', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
df.shape
# Out:
# (6497, 13)

# %%
df_august.shape
# Out:
# (7, 13)

# %%
new_df= pd.concat([df,df_august],axis=0,ignore_index=True)

# %%
new_df.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6494        17558     31-Jul-22           RT4                    3       6.0
# 6495        19563     31-Jul-22           RT4                    3       6.0
# 6496        17561     31-Jul-22           RT4                    3       4.0
# 6497        16559     01-Aug-22           RT1                   30      30.0
# 6498        19562     01-Aug-22           RT1                   21      30.0
# 6499        19563     01-Aug-22           RT1                   23      30.0
# 6500        19558     01-Aug-22           RT1                   30      40.0
# 6501        19560     01-Aug-22           RT1                   20      26.0
# 6502        17561     01-Aug-22           RT1                   18      26.0
# 6503        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct    room_class  property_name  category       city  mmm yy  \
# ...

# %%
new_df.shape
# Out:
# (6504, 14)

# %% [markdown]
# **6. Print revenue realized per city**

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_bookings=df_bookings.merge(df_hotels,on='property_id')

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 2  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 3  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 4  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        2.0           RT1          logtrip            5.0    Checked Out
# 2        4.0           RT1    direct online            5.0    Checked Out
# 3        2.0           RT1           others            4.0    Checked Out
# 4        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_bookings.groupby('city')['revenue_realized'].sum()
# Out:
# city
# Bangalore    420383550
# Delhi        294438788
# Hyderabad    325179310
# Mumbai       668602231
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **7. Print month by month revenue**

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134578 entries, 0 to 134577
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134578 non-null  object
#  1   property_id        134578 non-null  int64
#  2   booking_date       134578 non-null  object
#  3   check_in_date      134578 non-null  object
#  4   checkout_date      134578 non-null  object
#  5   no_guests          134578 non-null  float64
#  6   room_category      134578 non-null  object
#  7   booking_platform   134578 non-null  object
#  8   ratings_given      56679 non-null   float64
#  9   booking_status     134578 non-null  object
#  10  revenue_generated  134578 non-null  int64
#  11  revenue_realized   134578 non-null  int64
#  12  property_name      134578 non-null  object
#  13  category           134578 non-null  object
#  14  city               134578 non-null  object
# ...

# %%
df_bookings['check_in_date']=pd.to_datetime(df_bookings['check_in_date'],format='mixed',yearfirst=False,dayfirst=True)
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT13        16558     28-04-22    2022-05-01      4/5/2022
# 2  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 3  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 4  May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        2.0           RT1          logtrip            5.0    Checked Out
# 2        4.0           RT1    direct online            5.0    Checked Out
# 3        2.0           RT1           others            4.0    Checked Out
# 4        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134578 entries, 0 to 134577
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134578 non-null  object
#  1   property_id        134578 non-null  int64
#  2   booking_date       134578 non-null  object
#  3   check_in_date      134578 non-null  datetime64[ns]
#  4   checkout_date      134578 non-null  object
#  5   no_guests          134578 non-null  float64
#  6   room_category      134578 non-null  object
#  7   booking_platform   134578 non-null  object
#  8   ratings_given      56679 non-null   float64
#  9   booking_status     134578 non-null  object
#  10  revenue_generated  134578 non-null  int64
#  11  revenue_realized   134578 non-null  int64
#  12  property_name      134578 non-null  object
#  13  category           134578 non-null  object
#  14  city               134578 non-null  object
# ...

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT13        16558     28-04-22    2022-05-01      4/5/2022
# 2  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 3  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 4  May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        2.0           RT1          logtrip            5.0    Checked Out
# 2        4.0           RT1    direct online            5.0    Checked Out
# 3        2.0           RT1           others            4.0    Checked Out
# 4        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df_date['date']=pd.to_datetime(df_date['date'])
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_10880\1025413012.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_date['date']=pd.to_datetime(df_date['date'])

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday
# 3 2022-05-04  May 22    W 19  weekeday
# 4 2022-05-05  May 22    W 19  weekeday

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df_bookings=df_bookings.merge(df_date,left_on='check_in_date',right_on='date')
df_bookings.head(6)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT13        16558     28-04-22    2022-05-01      4/5/2022
# 2  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 3  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 4  May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
# 5  May012216558RT18        16558     26-04-22    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        2.0           RT1          logtrip            5.0    Checked Out
# 2        4.0           RT1    direct online            5.0    Checked Out
# 3        2.0           RT1           others            4.0    Checked Out
# 4        2.0           RT1           others            NaN      Cancelled
# ...

# %%
df_bookings[df_bookings['booking_id']=='May012216558RT16']
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 3  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 3        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 3               9100              9100  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no day_type
# 3 2022-05-01  May 22    W 19  weekend

# %%
df_bookings.drop('date',inplace=True,axis=1)

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT13        16558     28-04-22    2022-05-01      4/5/2022
# 2  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 3  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 4  May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        2.0           RT1          logtrip            5.0    Checked Out
# 2        4.0           RT1    direct online            5.0    Checked Out
# 3        2.0           RT1           others            4.0    Checked Out
# 4        2.0           RT1           others            NaN      Cancelled
#
# ...

# %%
df_bookings.groupby('mmm yy')['revenue_realized'].sum().sort_values(ascending=False)
# Out:
# mmm yy
# May 22    581822076
# Jul 22    572855948
# Jun 22    553925855
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **Exercise-1. Print revenue realized per hotel type**

# %%
df_bookings['property_name'].unique()
# Out:
# array(['Atliq Grands', 'Atliq Exotica', 'Atliq City', 'Atliq Blu',
#        'Atliq Bay', 'Atliq Palace', 'Atliq Seasons'], dtype=object)

# %%
df_bookings.groupby('property_name')['revenue_realized'].sum().sort_values(ascending=False)
# Out:
# property_name
# Atliq Exotica    320291568
# Atliq Palace     304081863
# Atliq City       285798439
# Atliq Blu        260851922
# Atliq Bay        260022118
# Atliq Grands     211471234
# Atliq Seasons     66086735
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **Exercise-2 Print average rating per city**

# %%
df_bookings[df_bookings['ratings_given'].isna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77899 entries, 0 to 134577
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   booking_id         77899 non-null  object
#  1   property_id        77899 non-null  int64
#  2   booking_date       77899 non-null  object
#  3   check_in_date      77899 non-null  datetime64[ns]
#  4   checkout_date      77899 non-null  object
#  5   no_guests          77899 non-null  float64
#  6   room_category      77899 non-null  object
#  7   booking_platform   77899 non-null  object
#  8   ratings_given      0 non-null      float64
#  9   booking_status     77899 non-null  object
#  10  revenue_generated  77899 non-null  int64
#  11  revenue_realized   77899 non-null  int64
#  12  property_name      77899 non-null  object
#  13  category           77899 non-null  object
#  14  city               77899 non-null  object
#  15  mmm yy             77899 non-null  object
# ...

# %%
df_bookings.groupby('city')['ratings_given'].mean().sort_values(ascending=False)
# Out:
# city
# Delhi        3.779265
# Hyderabad    3.661041
# Mumbai       3.650545
# Bangalore    3.407681
# Name: ratings_given, dtype: float64

# %% [markdown]
# **Exercise-3 Print a pie chart of revenue realized per booking platform**

# %%
df_bookings['booking_platform'].unique()
# Out:
# array(['others', 'logtrip', 'direct online', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.groupby('booking_platform')['revenue_realized'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='revenue_realized'>
